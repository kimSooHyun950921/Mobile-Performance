# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters
from sklearn.model_selection import train_test_split
import urllib
import csv
import cv2
import time
from PIL import Image

from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color


# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
# Out:
#                                             filename  width  height  \
# 0  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 1  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 2  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 3  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 4  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
#
#        class  xmin  ymin  xmax  ymax
# 0  clickable   212   749  1228   941
# 1  clickable     0  2138  1440  2676
# 2  clickable   496  1950   944  2664
# 3  clickable     0    96   224   320
# 4  clickable     0  1927   480  2119

# %% [markdown]
# # Preprocessing

# %%
csv_path = '/home/kimsoohyun/00-Research/02-Graph/02-image_detection/04-clickable/dataset/03-models/ob_model/workspace/trainig_demo/annotations/test.csv'
# training dataset
anns = pd.read_csv(csv_path)
anns.head()
# Out:
#                                             filename  width  height  \
# 0  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 1  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 2  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 3  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
# 4  /home/kimsoohyun/00-Research/02-Graph/02-image...   2960    1440
#
#        class  xmin  ymin  xmax  ymax
# 0  clickable   212   749  1228   941
# 1  clickable     0  2138  1440  2676
# 2  clickable   496  1950   944  2664
# 3  clickable     0    96   224   320
# 4  clickable     0  1927   480  2119

# %% [markdown]
# # Training

# %%
PRETRAINED_MODEL = '/home/kimsoohyun/00-Research/02-Graph/02-image_detection/04-clickable/dataset/05-keras_retinalnet/keras-retinanet/snapshots/_pretrained_model.h5'

URL_MODEL = 'https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_coco_best_v2.1.0.h5'
urllib.request.urlretrieve(URL_MODEL, PRETRAINED_MODEL)

print('Downloaded pretrained model to ' + PRETRAINED_MODEL)
# Out:
# Downloaded pretrained model to /home/kimsoohyun/00-Research/02-Graph/02-image_detection/04-clickable/dataset/05-keras_retinalnet/keras-retinanet/snapshots/_pretrained_model.h5

# %%
# %cd '/dataset/05-keras_retinalnet/keras-retinanet/snapshots'
# !/home/kimsoohyun/00-Research/02-Graph/02-image_detection/04-clickable/dataset/05-keras_retinalnet/keras-retinanet/keras_retinanet/bin/train.py --freeze-backbone --random-transform --weights {PRETRAINED_MODEL} --batch-size 8 --steps 500 --epochs 10 csv annotations.csv classes.csv
# Out:
# [Errno 2] No such file or directory: '/dataset/05-keras_retinalnet/keras-retinanet/snapshots'
# /home/kimsoohyun/00-Research/02-Graph/02-image_detection/04-clickable
# Using TensorFlow backend.
# 2020-04-27 13:53:37.384212: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory
# 2020-04-27 13:53:37.384312: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory
# 2020-04-27 13:53:37.384324: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Traceback (most recent call last):
# ...
